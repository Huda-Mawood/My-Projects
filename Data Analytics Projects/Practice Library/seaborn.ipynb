# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to read fill 
data= sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
data= sns.load_dataset("fmri") 
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.set(style="dark")
fmri = sns.load_dataset("fmri")
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
df=sns.load_dataset("anscombe")
sns.lmplot(x="x",y="y",data=df)

# %%
#palette
sns.palplot(sns.color_palette("inferno",8))

# %%
col=sns.color_palette()
sns.palplot(col)

# %%
sns.palplot(sns.color_palette("Purples"))

# %%
sns.palplot(sns.color_palette("bone_r",8))

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data=sns.FacetGrid(df,col='sex',hue='day')
data.map(plt.scatter,"total_bill","tip",edgecolor='k').add_legend()

# %%
data=sns.FacetGrid(df,row="smoker",col="time")
data.map(plt.hist,"total_bill",bins=13,color="green")

# %%
graph=sns.PairGrid(df)
graph=graph.map_upper(sns.scatterplot)
graph=graph.map_lower(sns.kdeplot)
graph=graph.map_diag(sns.histplot)

# %%
graph=sns.PairGrid(df,hue="day")
graph=graph.map_diag(sns.histplot)
graph=graph.map_offdiag(sns.scatterplot)
graph=graph.add_legend()

# %%
df=pd.read_csv("iris-write-from-docker.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
ss=sns.displot(df)

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df,kind="reg")

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df,kind="kde",color="y")

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df,kind="hex")

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(df['petal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='class',palette='YlGnBu')

# %%
sns.rugplot(df)
# Out:
# <Axes: >

# %%
sns.rugplot(df['class'])
# Out:
# <Axes: xlabel='class'>

# %%
sns.set_style('dark')
plt.figure(figsize=(8,6))
sns.set_context("poster",font_scale=.5)
sns.despine(left=True,bottom=True)
sns.jointplot(x="sepal_width",y="petal_width",data=df,kind='reg')

# %%
sns.barplot(x="sepal_length",y="petal_length",data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
State = ["Rajasthan", "Bihar", "Madhya Pradesh",
         "Gujarat", "Maharashtra"]
growth = [342239, 94163, 308245, 196024, 307713]
df = pd.DataFrame({"State": State,
                   "Growth": growth})
sns.barplot(x="State",y="Growth",data=df,order=df.sort_values("Growth",ascending = Tri).State)
# Out:
# <Axes: xlabel='State', ylabel='Growth'>

# %%
#std--var--mean--median--cov
sns.barplot(x="sepal_length",y="petal_length",data=df,estimator=np.std)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.countplot(x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("iris-write-from-docker.csv")

# %%
sns.boxplot(x='class',y="petal_length",data=df,orient="v")
# Out:
# <Axes: xlabel='class', ylabel='petal_length'>

# %%
sns.violinplot(x='class',y="sepal_length",data=df)
# Out:
# <Axes: xlabel='class', ylabel='sepal_length'>

# %%
sns.stripplot(x="class",y="petal_length",data=df,jitter=True)
# Out:
# <Axes: xlabel='class', ylabel='petal_length'>

# %%
sns.swarmplot(x="class",y="petal_length",data=df)
# Out:
# <Axes: xlabel='class', ylabel='petal_length'>
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x="class",y="petal_length",data=df,color='k')
sns.swarmplot(x="class",y="petal_length",data=df,palette="copper")
# Out:
# /tmp/ipykernel_97/2488781088.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="class",y="petal_length",data=df,palette="copper")
# <Axes: xlabel='class', ylabel='petal_length'>
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data = np.random.randint(low = 1,
                         high = 100,
                         size = (10, 10))
hm = sns.heatmap(data = data)

# %%
df_mx=df.corr()
sns.heatmap(df_mx,annot=True,cmap='copper')
# Out:
# /tmp/ipykernel_97/1018134816.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mx=df.corr()
# <Axes: >
