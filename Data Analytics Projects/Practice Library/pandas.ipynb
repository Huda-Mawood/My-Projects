# %%
import pandas as pd
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 0               1  I agree                   None of these  18-24 years old
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 4               5  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 12922       12923  I agree  I am a developer by profession  25-34 years old
# 12923       12924  I agree  I am a developer by profession  45-54 years old
# 12924       12925  I agree  I am a developer by profession  35-44 years old
# 12925       12926  I agree  I am a developer by profession  25-34 years old
# 12926       12927  I agree  I am a developer by profession  45-54 years old
#
# ...

# %%
df.shape
# Out:
# (12927, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12927 entries, 0 to 12926
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           12927 non-null  int64
#  1   Q120                                 12927 non-null  object
#  2   MainBranch                           12927 non-null  object
#  3   Age                                  12927 non-null  object
#  4   Employment                           12779 non-null  object
#  5   RemoteWork                           10789 non-null  object
#  6   CodingActivities                     10781 non-null  object
#  7   EdLevel                              12790 non-null  object
#  8   LearnCode                            12744 non-null  object
#  9   LearnCodeOnline                      10202 non-null  object
#  10  LearnCodeCoursesCert                 5142 non-null   object
# ...

# %%
df.head(4)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
#
# ...

# %%
df.tail(5)
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 12922       12923  I agree  I am a developer by profession  25-34 years old
# 12923       12924  I agree  I am a developer by profession  45-54 years old
# 12924       12925  I agree  I am a developer by profession  35-44 years old
# 12925       12926  I agree  I am a developer by profession  25-34 years old
# 12926       12927  I agree  I am a developer by profession  45-54 years old
#
#                                               Employment RemoteWork  \
# 12922  Employed, full-time;Independent contractor, fr...     Remote
# 12923  Employed, full-time;Independent contractor, fr...  In-person
# 12924                                Employed, full-time  In-person
# 12925                 Not employed, but looking for work        NaN
# 12926  Independent contractor, freelancer, or self-em...     Remote
#
#                                         CodingActivities  \
# ...

# %%
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}

# %%
df=pd.DataFrame(people)
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.email
# Out:
# 0     hodamawood@gmail.com
# 1       alyaaezz@gmail.com
# 2    manarhamada@gmail.com
# Name: email, dtype: object

# %%
df['email']
# Out:
# 0     hodamawood@gmail.com
# 1       alyaaezz@gmail.com
# 2    manarhamada@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df[['last','email']]
# Out:
#      last                  email
# 0  mawood   hodamawood@gmail.com
# 1     ezz     alyaaezz@gmail.com
# 2  hamada  manarhamada@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                    hoda
# last                   mawood
# email    hodamawood@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first    last                 email
# 0   hoda  mawood  hodamawood@gmail.com
# 1  alyaa     ezz    alyaaezz@gmail.com

# %%
df.iloc[[0,2],2]
# Out:
# 0     hodamawood@gmail.com
# 2    manarhamada@gmail.com
# Name: email, dtype: object

# %%
df.loc[1]
# Out:
# first                 alyaa
# last                    ezz
# email    alyaaezz@gmail.com
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#    first    last                  email
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.loc[[0,1],'first']
# Out:
# 0     hoda
# 1    alyaa
# Name: first, dtype: object

# %%
df.loc[[0,1],['first','last']]
# Out:
#    first    last
# 0   hoda  mawood
# 1  alyaa     ezz

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['MainBranch']
# Out:
# 0                         None of these
# 1        I am a developer by profession
# 2        I am a developer by profession
# 3        I am a developer by profession
# 4        I am a developer by profession
#                       ...
# 89179    I am a developer by profession
# 89180    I am a developer by profession
# 89181       I code primarily as a hobby
# 89182    I am a developer by profession
# 89183    I am a developer by profession
# Name: MainBranch, Length: 89184, dtype: object

# %%
df.loc[1]
# Out:
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
# RemoteWork                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 1, Length: 83, dtype: object

# %%
df.loc[[0,1,2],['MainBranch','RemoteWork']]
# Out:
#                        MainBranch                            RemoteWork
# 0                   None of these                                   NaN
# 1  I am a developer by profession                                Remote
# 2  I am a developer by profession  Hybrid (some remote, some in-person)

# %%
df.loc[0,'RemoteWork']
# Out:
# nan

# %%
df.loc[0:4,'MainBranch':'RemoteWork']
# Out:
#                        MainBranch              Age  \
# 0                   None of these  18-24 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  45-54 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote

# %%
#indexes
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}
df=pd.DataFrame(people)
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.set_index('email')
# Out:
#                        first    last
# email
# hodamawood@gmail.com    hoda  mawood
# alyaaezz@gmail.com     alyaa     ezz
# manarhamada@gmail.com  manar  hamada

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                        first    last
# email
# hodamawood@gmail.com    hoda  mawood
# alyaaezz@gmail.com     alyaa     ezz
# manarhamada@gmail.com  manar  hamada

# %%
df.loc['alyaaezz@gmail.com']
# Out:
# first    alyaa
# last       ezz
# Name: alyaaezz@gmail.com, dtype: object

# %%
df.loc['alyaaezz@gmail.com','first']
# Out:
# 'alyaa'

# %%
df.iloc[1]
# Out:
# first    alyaa
# last       ezz
# Name: alyaaezz@gmail.com, dtype: object

# %%
df.reset_index()
# Out:
#                    email  first    last
# 0   hodamawood@gmail.com   hoda  mawood
# 1     alyaaezz@gmail.com  alyaa     ezz
# 2  manarhamada@gmail.com  manar  hamada

# %%
df
# Out:
#                        first    last
# email
# hodamawood@gmail.com    hoda  mawood
# alyaaezz@gmail.com     alyaa     ezz
# manarhamada@gmail.com  manar  hamada

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                    email  first    last
# 0   hodamawood@gmail.com   hoda  mawood
# 1     alyaaezz@gmail.com  alyaa     ezz
# 2  manarhamada@gmail.com  manar  hamada

# %%
df=pd.read_csv('survey_results_public.csv',index_col='ResponseId')
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='qname')
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
schema_df.loc['MetaInfo']
# Out:
# qid                       QID12
# question      Browser Meta Info
# force_resp                False
# type                       Meta
# selector                Browser
# Name: MetaInfo, dtype: object

# %%
schema_df.loc['MetaInfo','question':'selector']
# Out:
# question      Browser Meta Info
# force_resp                False
# type                       Meta
# selector                Browser
# Name: MetaInfo, dtype: object

# %%
schema_df.loc['MetaInfo',['question','selector']]
# Out:
# question    Browser Meta Info
# selector              Browser
# Name: MetaInfo, dtype: object

# %%
schema_df.sort_index()
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID324  For the AI tools you use as part of your devel...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AINext        QID320  Thinking about how your workflow and process c...
# AIOpen        QID321  Please describe how you would expect your work...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     MAVR
# ...

# %%
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID324  For the AI tools you use as part of your devel...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AINext        QID320  Thinking about how your workflow and process c...
# AIOpen        QID321  Please describe how you would expect your work...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     MAVR
# ...

# %%
schema_df.sort_index(ascending=True)
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID324  For the AI tools you use as part of your devel...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AINext        QID320  Thinking about how your workflow and process c...
# AIOpen        QID321  Please describe how you would expect your work...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     MAVR
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                  qid                                           question  \
# qname
# YearsCodePro   QID34  NOT including education, how many years have y...
# YearsCode      QID32  Including any education, how many years have y...
# WorkExp       QID288  How many years of working experience do you have?
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# ...              ...                                                ...
# AIOpen        QID321  Please describe how you would expect your work...
# AINext        QID320  Thinking about how your workflow and process c...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIAcc         QID324  For the AI tools you use as part of your devel...
#
#              force_resp    type selector
# qname
# YearsCodePro      False      MC       DL
# ...

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df
# Out:
#            qname     qid                                           question  \
# 0          AIAcc  QID324  For the AI tools you use as part of your devel...
# 1          AIBen  QID316  How much do you trust the accuracy of the outp...
# 2          AIDev  QID328  Which <b>AI-powered developer tools</b> did yo...
# 3         AINext  QID320  Thinking about how your workflow and process c...
# 4         AIOpen  QID321  Please describe how you would expect your work...
# ..           ...     ...                                                ...
# 73     ToolsTech  QID275  Which <b>developer </b><strong>tools for compi...
# 74      Webframe  QID264  Which <b>web frameworks and web technologies</...
# 75       WorkExp  QID288  How many years of working experience do you have?
# 76     YearsCode   QID32  Including any education, how many years have y...
# 77  YearsCodePro   QID34  NOT including education, how many years have y...
#
#    force_resp    type selector
# ...

# %%
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df[['last','email']]
# Out:
#      last                  email
# 0  mawood   hodamawood@gmail.com
# 1     ezz     alyaaezz@gmail.com
# 2  hamada  manarhamada@gmail.com

# %%
df.loc[0]
# Out:
# first                    hoda
# last                   mawood
# email    hodamawood@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0,1,2],'last']
# Out:
# 0    mawood
# 1       ezz
# 2    hamada
# Name: last, dtype: object

# %%
df.iloc[0]
# Out:
# first                    hoda
# last                   mawood
# email    hodamawood@gmail.com
# Name: 0, dtype: object

# %%
df['last']=='hamada'
# Out:
# 0    False
# 1    False
# 2     True
# Name: last, dtype: bool

# %%
filt=df['last']=='hamada'
df[filt]
# Out:
#    first    last                  email
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.loc[filt]
# Out:
#    first    last                  email
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.loc[filt,'email']
# Out:
# 2    manarhamada@gmail.com
# Name: email, dtype: object

# %%
filt=(df['last']=='ezz')&(df['first']=='alyaa')
df[filt]
# Out:
#    first last               email
# 1  alyaa  ezz  alyaaezz@gmail.com

# %%
filt=(df['last']=='mawood')|(df['first']=='alyaa')
df[filt]
# Out:
#    first    last                 email
# 0   hoda  mawood  hodamawood@gmail.com
# 1  alyaa     ezz    alyaaezz@gmail.com

# %%
df.loc[~filt]
# Out:
#    first    last                  email
# 2  manar  hamada  manarhamada@gmail.com

# %%
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
high_salary=(df['ConvertedCompYearly']>60000)
df.loc[high_salary,['Age','Employment','ConvertedCompYearly']]
# Out:
#                    Age           Employment  ConvertedCompYearly
# 1      25-34 years old  Employed, full-time             285000.0
# 2      45-54 years old  Employed, full-time             250000.0
# 3      25-34 years old  Employed, full-time             156000.0
# 5      35-44 years old  Employed, full-time              96828.0
# 6      35-44 years old  Employed, full-time             135000.0
# ...                ...                  ...                  ...
# 89155  25-34 years old  Employed, full-time              63199.0
# 89156  25-34 years old  Employed, full-time             195000.0
# 89157  25-34 years old  Employed, full-time             319711.0
# 89170  25-34 years old  Employed, full-time              64254.0
# 89171  25-34 years old  Employed, full-time              61041.0
#
# [29605 rows x 3 columns]

# %%
SurveyLengths=['Appropriate in length']
filt=df['SurveyLength'].isin(SurveyLengths)
df.loc[filt,['SurveyLength','Employment','ConvertedCompYearly']]
# Out:
#                 SurveyLength  \
# 1      Appropriate in length
# 2      Appropriate in length
# 3      Appropriate in length
# 4      Appropriate in length
# 5      Appropriate in length
# ...                      ...
# 89172  Appropriate in length
# 89175  Appropriate in length
# 89178  Appropriate in length
# 89182  Appropriate in length
# 89183  Appropriate in length
#
#                                               Employment  ConvertedCompYearly
# 1                                    Employed, full-time             285000.0
# 2                                    Employed, full-time             250000.0
# 3                                    Employed, full-time             156000.0
# 4      Employed, full-time;Independent contractor, fr...              23456.0
# 5                                    Employed, full-time              96828.0
# ...                                                  ...                  ...
# ...

# %%
filt=df['LearnCode'].str.contains('Books',na=False)
df.loc[filt,['ResponseId','LearnCode']]
# Out:
#        ResponseId                                          LearnCode
# 1               2  Books / Physical media;Colleague;Friend or fam...
# 2               3  Books / Physical media;Colleague;On the job tr...
# 4               5  Books / Physical media;Online Courses or Certi...
# 5               6  Books / Physical media;Colleague;Online Course...
# 7               8  Books / Physical media;Online Courses or Certi...
# ...           ...                                                ...
# 89161       89162  Books / Physical media;Other online resources ...
# 89166       89167  Books / Physical media;Hackathons (virtual or ...
# 89172       89173  Books / Physical media;School (i.e., Universit...
# 89177       89178  Books / Physical media;Other online resources ...
# 89181       89182  Books / Physical media;Hackathons (virtual or ...
#
# [45406 rows x 2 columns]

# %%
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.columns=['First_Name','Last_Name','Email']

# %%
df
# Out:
#   First_Name Last_Name                  Email
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                  EMAIL
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name                  email
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#   first name last name                  email
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df
# Out:
#   first_name last_name                  email
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.rename(columns={'email':'gmail'})
# Out:
#   first_name last_name                  gmail
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df
# Out:
#   first_name last_name                  email
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df.rename(columns={'email':'gmail'},inplace=True)

# %%
df
# Out:
#   first_name last_name                  gmail
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
df
# Out:
#   first_name last_name                  gmail
# 0       hoda    mawood   hodamawood@gmail.com
# 1      alyaa       ezz     alyaaezz@gmail.com
# 2      manar    hamada  manarhamada@gmail.com

# %%
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df.loc[0,['first']]=['hadoosh']

# %%
df
# Out:
#      first    last                  email
# 0  hadoosh  mawood   hodamawood@gmail.com
# 1    alyaa     ezz     alyaaezz@gmail.com
# 2    manar  hamada  manarhamada@gmail.com

# %%
import pandas as pd
people={
    "first":['hoda','alyaa','manar'],
    "last":['mawood','ezz','hamada'],
    "email":['hodamawood@gmail.com','alyaaezz@gmail.com','manarhamada@gmail.com']
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
filt=(df['email']=='hodamawood@gmail.com')
df.loc[filt,'last']='maoud'

# %%
df
# Out:
#    first    last                  email
# 0   hoda   maoud   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df['email'].str.lower()
# Out:
# 0     hodamawood@gmail.com
# 1       alyaaezz@gmail.com
# 2    manarhamada@gmail.com
# Name: email, dtype: object

# %%
df['email']=df['email'].str.upper()

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df['email']=df['email'].str.upper()

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   HODAMAWOOD@GMAIL.COM
# 1  alyaa     ezz     ALYAAEZZ@GMAIL.COM
# 2  manar  hamada  MANARHAMADA@GMAIL.COM

# %%
df['email'].apply(len)
# Out:
# 0    20
# 1    18
# 2    21
# Name: email, dtype: int64

# %%
def updata_last(last):
    return last.upper()
df['last']=df['last'].apply(updata_last)

# %%
df
# Out:
#    first    last                  email
# 0   hoda  MAWOOD   HODAMAWOOD@GMAIL.COM
# 1  alyaa     EZZ     ALYAAEZZ@GMAIL.COM
# 2  manar  HAMADA  MANARHAMADA@GMAIL.COM

# %%
df['last']=df['last'].apply(lambda x: x.lower())

# %%
df
# Out:
#    first    last                  email
# 0   hoda  mawood   HODAMAWOOD@GMAIL.COM
# 1  alyaa     ezz     ALYAAEZZ@GMAIL.COM
# 2  manar  hamada  MANARHAMADA@GMAIL.COM

# %%
len(df['first'])
# Out:
# 3

# %%
df.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(len,axis='rows')
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(lambda x: x.min())
# Out:
# first                 alyaa
# last                    ezz
# email    ALYAAEZZ@GMAIL.COM
# dtype: object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      4     6     20
# 1      5     3     18
# 2      5     6     21

# %%
df.applymap(str.lower)
# Out:
#    first    last                  email
# 0   hoda  mawood   hodamawood@gmail.com
# 1  alyaa     ezz     alyaaezz@gmail.com
# 2  manar  hamada  manarhamada@gmail.com

# %%
df['first'].map({'hoda':'hadoosh','alyaa':'lolo'})
# Out:
# 0    hadoosh
# 1       lolo
# 2        NaN
# Name: first, dtype: object

# %%
df['first'].replace({'hoda':'hadoosh','alyaa':'lolo'})
# Out:
# 0    hadoosh
# 1       lolo
# 2      manar
# Name: first, dtype: object

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.rename(columns={'ConvertedCompYearly':'salary'})
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...
